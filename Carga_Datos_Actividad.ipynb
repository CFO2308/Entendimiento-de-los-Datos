# %%
import json
import pandas as pd
import numpy as np

# %%
# %pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
Belize_data = pd.read_csv("listings.csv")
Belize_data
# Out:
#                        id                                       listing_url  \
# 0                   36690                https://www.airbnb.com/rooms/36690
# 1                  120115               https://www.airbnb.com/rooms/120115
# 2                  120116               https://www.airbnb.com/rooms/120116
# 3                  152512               https://www.airbnb.com/rooms/152512
# 4                  152922               https://www.airbnb.com/rooms/152922
# ...                   ...                                               ...
# 3352  1319855705868239638  https://www.airbnb.com/rooms/1319855705868239638
# 3353  1320403120055694274  https://www.airbnb.com/rooms/1320403120055694274
# 3354  1320433954346366057  https://www.airbnb.com/rooms/1320433954346366057
# 3355  1321127393035986258  https://www.airbnb.com/rooms/1321127393035986258
# 3356  1321194277633347377  https://www.airbnb.com/rooms/1321194277633347377
#
#            scrape_id last_scraped       source  \
# ...

# %%
pd.options.display.max_rows = 10
print(Belize_data)
# Out:
#                        id                                       listing_url  \
# 0                   36690                https://www.airbnb.com/rooms/36690
# 1                  120115               https://www.airbnb.com/rooms/120115
# 2                  120116               https://www.airbnb.com/rooms/120116
# 3                  152512               https://www.airbnb.com/rooms/152512
# 4                  152922               https://www.airbnb.com/rooms/152922
# ...                   ...                                               ...
# 3352  1319855705868239638  https://www.airbnb.com/rooms/1319855705868239638
# 3353  1320403120055694274  https://www.airbnb.com/rooms/1320403120055694274
# 3354  1320433954346366057  https://www.airbnb.com/rooms/1320433954346366057
# 3355  1321127393035986258  https://www.airbnb.com/rooms/1321127393035986258
# 3356  1321194277633347377  https://www.airbnb.com/rooms/1321194277633347377
#
#            scrape_id last_scraped       source  \
# ...

# %%
Belize_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3357 entries, 0 to 3356
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3357 non-null   int64
#  1   listing_url                                   3357 non-null   object
#  2   scrape_id                                     3357 non-null   int64
#  3   last_scraped                                  3357 non-null   object
#  4   source                                        3357 non-null   object
#  5   name                                          3357 non-null   object
#  6   description                                   3079 non-null   object
#  7   neighborhood_overview                         1800 non-null   object
#  8   picture_url                                   3357 non-null   object
# ...

# %%
data = Belize_data.iloc[: ,[1,4,5,7]]
data
# Out:
#                                            listing_url       source  \
# 0                   https://www.airbnb.com/rooms/36690  city scrape
# 1                  https://www.airbnb.com/rooms/120115  city scrape
# 2                  https://www.airbnb.com/rooms/120116  city scrape
# 3                  https://www.airbnb.com/rooms/152512  city scrape
# 4                  https://www.airbnb.com/rooms/152922  city scrape
# ...                                                ...          ...
# 3352  https://www.airbnb.com/rooms/1319855705868239638  city scrape
# 3353  https://www.airbnb.com/rooms/1320403120055694274  city scrape
# 3354  https://www.airbnb.com/rooms/1320433954346366057  city scrape
# 3355  https://www.airbnb.com/rooms/1321127393035986258  city scrape
# 3356  https://www.airbnb.com/rooms/1321194277633347377  city scrape
#
#                                                    name  \
# 0                                      Mo's Cozy Cabana
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3357 entries, 0 to 3356
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   listing_url            3357 non-null   object
#  1   source                 3357 non-null   object
#  2   name                   3357 non-null   object
#  3   neighborhood_overview  1800 non-null   object
# dtypes: object(4)
# memory usage: 105.0+ KB

# %%
data.to_csv("Belize.csv")
